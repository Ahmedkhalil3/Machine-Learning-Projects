# %% [markdown]
# # 01 Exploring the Data

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Import

# %%
df = pd.read_csv("../data/SCFP2019.csv.gz")
print("df shape:", df.shape)
df.head()
# Out:
# df shape: (28885, 351)
#    YY1  Y1          WGT  HHSEX  AGE  AGECL  EDUC  EDCL  MARRIED  KIDS  ...  \
# 0    1  11  6119.779308      2   75      6    12     4        2     0  ...
# 1    1  12  4712.374912      2   75      6    12     4        2     0  ...
# 2    1  13  5145.224455      2   75      6    12     4        2     0  ...
# 3    1  14  5297.663412      2   75      6    12     4        2     0  ...
# 4    1  15  4761.812371      2   75      6    12     4        2     0  ...
#
#    NWCAT  INCCAT  ASSETCAT  NINCCAT  NINC2CAT  NWPCTLECAT  INCPCTLECAT  \
# 0      5       3         6        3         2          10            6
# 1      5       3         6        3         1          10            5
# 2      5       3         6        3         1          10            5
# 3      5       2         6        2         1          10            4
# 4      5       3         6        3         1          10            5
#
#    NINCPCTLECAT  INCQRTCAT  NINCQRTCAT
# 0             6          3           3
# 1             5          2           2
# 2             5          2           2
# 3             4          2           2
# 4             5          2           2
#
# [5 rows x 351 columns]

# %%
df_fear = df[df["TURNFEAR"] == 1]
print("df_fear shape:", df_fear.shape)
# Out:
# df_fear shape: (4623, 351)

# %% [markdown]
# ## Explore

# %% [markdown]
# ### Age Feature

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
age_groups = df_fear["AGECL"].unique()
print("Age Groups:", age_groups)
# Out:
# Age Groups: [3 5 1 2 4 6]

# %%
agecl_dict = {
    1: "Under 35",
    2: "35-44",
    3: "45-54",
    4: "55-64",
    5: "65-74",
    6: "75 or Older",
}

age_cl = df_fear["AGECL"].replace(agecl_dict)
age_cl.head()
# Out:
# 5    45-54
# 6    45-54
# 7    45-54
# 8    45-54
# 9    45-54
# Name: AGECL, dtype: object

# %%
age_cl.value_counts().plot(
    kind="bar",
    xlabel="Age Group",
    ylabel="Count",
    title="Distribution of Age Groups among Customers Who Turned to Fear",
);

# %%
df_fear["AGE"].hist(bins=10)
plt.xlabel("Age")
plt.ylabel("Frequency (count)")
plt.title("Credit Fearful: Age Distribution");

# %% [markdown]
# ### Income Feature

# %%
inccat_dict = {
    1: "0-20",
    2: "21-39.9",
    3: "40-59.9",
    4: "60-79.9",
    5: "80-89.9",
    6: "90-100",
}

df_inccat =(
    df["INCCAT"]
    .replace(inccat_dict)
    .groupby(df["TURNFEAR"])
    .value_counts(normalize=True)
    .rename("frequency")
    .to_frame()\
    .reset_index()
) 
df_inccat
# Out:
#     TURNFEAR   INCCAT  frequency
# 0          0   90-100   0.297296
# 1          0  60-79.9   0.174841
# 2          0  40-59.9   0.143146
# 3          0     0-20   0.140343
# 4          0  21-39.9   0.135933
# 5          0  80-89.9   0.108441
# 6          1     0-20   0.288125
# 7          1  21-39.9   0.256327
# 8          1  40-59.9   0.228856
# 9          1  60-79.9   0.132598
# 10         1   90-100   0.048886
# 11         1  80-89.9   0.045209

# %%
sns.barplot(
    x="INCCAT",
    y="frequency",
    hue="TURNFEAR",
    data=df_inccat,
    order=inccat_dict.values()
)
plt.xlabel("Income Category")
plt.ylabel("Frequency (%)")
plt.title("Income Distribution: Credit Fearful vs. Non-fearful");

# %% [markdown]
# ### Assets

# %%
asset_house_corr = df["ASSET"].corr(df["HOUSES"])
print("SCF: Asset Houses Correlation:", asset_house_corr)
# Out:
# SCF: Asset Houses Correlation: 0.5198273544779253

# %%
asset_house_corr = df_fear["ASSET"].corr(df_fear["HOUSES"])
print("Credit Fearful: Asset Houses Correlation:", asset_house_corr)
# Out:
# Credit Fearful: Asset Houses Correlation: 0.583287973597916

# %%
cols = ["ASSET", "HOUSES", "INCOME", "DEBT", "EDUC"]
corr = df[cols].corr()
corr.style.background_gradient(axis=None)
# Out:
# <style type="text/css">
# #T_73b4b_row0_col0, #T_73b4b_row1_col1, #T_73b4b_row2_col2, #T_73b4b_row3_col3, #T_73b4b_row4_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_73b4b_row0_col1, #T_73b4b_row1_col0 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_73b4b_row0_col2, #T_73b4b_row2_col0 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_73b4b_row0_col3, #T_73b4b_row3_col0 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_73b4b_row0_col4, #T_73b4b_row2_col3, #T_73b4b_row3_col2, #T_73b4b_row4_col0 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_73b4b_row1_col2, #T_73b4b_row2_col1 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_73b4b_row1_col3, #T_73b4b_row3_col1 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_73b4b_row1_col4, #T_73b4b_row4_col1 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_73b4b_row2_col4, #T_73b4b_row4_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_73b4b_row3_col4, #T_73b4b_row4_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_73b4b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73b4b_level0_col0" class="col_heading level0 col0" >ASSET</th>
#       <th id="T_73b4b_level0_col1" class="col_heading level0 col1" >HOUSES</th>
#       <th id="T_73b4b_level0_col2" class="col_heading level0 col2" >INCOME</th>
#       <th id="T_73b4b_level0_col3" class="col_heading level0 col3" >DEBT</th>
#       <th id="T_73b4b_level0_col4" class="col_heading level0 col4" >EDUC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73b4b_level0_row0" class="row_heading level0 row0" >ASSET</th>
#       <td id="T_73b4b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_73b4b_row0_col1" class="data row0 col1" >0.519827</td>
#       <td id="T_73b4b_row0_col2" class="data row0 col2" >0.622429</td>
#       <td id="T_73b4b_row0_col3" class="data row0 col3" >0.261250</td>
#       <td id="T_73b4b_row0_col4" class="data row0 col4" >0.116673</td>
#     </tr>
#     <tr>
#       <th id="T_73b4b_level0_row1" class="row_heading level0 row1" >HOUSES</th>
#       <td id="T_73b4b_row1_col0" class="data row1 col0" >0.519827</td>
#       <td id="T_73b4b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_73b4b_row1_col2" class="data row1 col2" >0.247852</td>
#       <td id="T_73b4b_row1_col3" class="data row1 col3" >0.266661</td>
#       <td id="T_73b4b_row1_col4" class="data row1 col4" >0.169300</td>
#     </tr>
#     <tr>
#       <th id="T_73b4b_level0_row2" class="row_heading level0 row2" >INCOME</th>
#       <td id="T_73b4b_row2_col0" class="data row2 col0" >0.622429</td>
#       <td id="T_73b4b_row2_col1" class="data row2 col1" >0.247852</td>
#       <td id="T_73b4b_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_73b4b_row2_col3" class="data row2 col3" >0.114646</td>
#       <td id="T_73b4b_row2_col4" class="data row2 col4" >0.069400</td>
#     </tr>
#     <tr>
#       <th id="T_73b4b_level0_row3" class="row_heading level0 row3" >DEBT</th>
#       <td id="T_73b4b_row3_col0" class="data row3 col0" >0.261250</td>
#       <td id="T_73b4b_row3_col1" class="data row3 col1" >0.266661</td>
#       <td id="T_73b4b_row3_col2" class="data row3 col2" >0.114646</td>
#       <td id="T_73b4b_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_73b4b_row3_col4" class="data row3 col4" >0.054179</td>
#     </tr>
#     <tr>
#       <th id="T_73b4b_level0_row4" class="row_heading level0 row4" >EDUC</th>
#       <td id="T_73b4b_row4_col0" class="data row4 col0" >0.116673</td>
#       <td id="T_73b4b_row4_col1" class="data row4 col1" >0.169300</td>
#       <td id="T_73b4b_row4_col2" class="data row4 col2" >0.069400</td>
#       <td id="T_73b4b_row4_col3" class="data row4 col3" >0.054179</td>
#       <td id="T_73b4b_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
corr = df_fear[cols].corr()
corr.style.background_gradient(axis=None)
# Out:
# <style type="text/css">
# #T_68f91_row0_col0, #T_68f91_row1_col1, #T_68f91_row2_col2, #T_68f91_row3_col3, #T_68f91_row4_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_68f91_row0_col1, #T_68f91_row1_col0 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_68f91_row0_col2, #T_68f91_row2_col0 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_68f91_row0_col3, #T_68f91_row3_col0 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_68f91_row0_col4, #T_68f91_row4_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_68f91_row1_col2, #T_68f91_row2_col1 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_68f91_row1_col3, #T_68f91_row3_col1 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_68f91_row1_col4, #T_68f91_row4_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_68f91_row2_col3, #T_68f91_row3_col2 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_68f91_row2_col4, #T_68f91_row4_col2 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_68f91_row3_col4, #T_68f91_row4_col3 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# </style>
# <table id="T_68f91">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68f91_level0_col0" class="col_heading level0 col0" >ASSET</th>
#       <th id="T_68f91_level0_col1" class="col_heading level0 col1" >HOUSES</th>
#       <th id="T_68f91_level0_col2" class="col_heading level0 col2" >INCOME</th>
#       <th id="T_68f91_level0_col3" class="col_heading level0 col3" >DEBT</th>
#       <th id="T_68f91_level0_col4" class="col_heading level0 col4" >EDUC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68f91_level0_row0" class="row_heading level0 row0" >ASSET</th>
#       <td id="T_68f91_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_68f91_row0_col1" class="data row0 col1" >0.583288</td>
#       <td id="T_68f91_row0_col2" class="data row0 col2" >0.722074</td>
#       <td id="T_68f91_row0_col3" class="data row0 col3" >0.474658</td>
#       <td id="T_68f91_row0_col4" class="data row0 col4" >0.113536</td>
#     </tr>
#     <tr>
#       <th id="T_68f91_level0_row1" class="row_heading level0 row1" >HOUSES</th>
#       <td id="T_68f91_row1_col0" class="data row1 col0" >0.583288</td>
#       <td id="T_68f91_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_68f91_row1_col2" class="data row1 col2" >0.264099</td>
#       <td id="T_68f91_row1_col3" class="data row1 col3" >0.962629</td>
#       <td id="T_68f91_row1_col4" class="data row1 col4" >0.160348</td>
#     </tr>
#     <tr>
#       <th id="T_68f91_level0_row2" class="row_heading level0 row2" >INCOME</th>
#       <td id="T_68f91_row2_col0" class="data row2 col0" >0.722074</td>
#       <td id="T_68f91_row2_col1" class="data row2 col1" >0.264099</td>
#       <td id="T_68f91_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_68f91_row2_col3" class="data row2 col3" >0.172393</td>
#       <td id="T_68f91_row2_col4" class="data row2 col4" >0.133170</td>
#     </tr>
#     <tr>
#       <th id="T_68f91_level0_row3" class="row_heading level0 row3" >DEBT</th>
#       <td id="T_68f91_row3_col0" class="data row3 col0" >0.474658</td>
#       <td id="T_68f91_row3_col1" class="data row3 col1" >0.962629</td>
#       <td id="T_68f91_row3_col2" class="data row3 col2" >0.172393</td>
#       <td id="T_68f91_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_68f91_row3_col4" class="data row3 col4" >0.177386</td>
#     </tr>
#     <tr>
#       <th id="T_68f91_level0_row4" class="row_heading level0 row4" >EDUC</th>
#       <td id="T_68f91_row4_col0" class="data row4 col0" >0.113536</td>
#       <td id="T_68f91_row4_col1" class="data row4 col1" >0.160348</td>
#       <td id="T_68f91_row4_col2" class="data row4 col2" >0.133170</td>
#       <td id="T_68f91_row4_col3" class="data row4 col3" >0.177386</td>
#       <td id="T_68f91_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Education

# %%
df_educ = (
    df["EDUC"]
    .groupby(df["TURNFEAR"])
    .value_counts(normalize=True)
    .rename("Frequency")
    .to_frame()
    .reset_index()
)

df_educ.head()
# Out:
#    TURNFEAR  EDUC  Frequency
# 0         0    12   0.257481
# 1         0     8   0.192029
# 2         0    13   0.149823
# 3         0     9   0.129833
# 4         0    14   0.096117

# %%
sns.barplot(
    x="EDUC",
    y="Frequency",
    hue="TURNFEAR",
    data=df_educ,
)
plt.xlabel("Education Level")
plt.ylabel("Frequency (%)")
plt.title("Educational Attainment: Credit Fearful vs. Non-fearful");

# %% [markdown]
# ### Debt

# %%
df.plot(
    kind="scatter",
    x="DEBT",
    y="ASSET"
);

# %%
df_fear.plot(
    kind="scatter",
    x="DEBT",
    y="ASSET"
);

# %%
df.plot(
    kind="scatter",
    x="DEBT",
    y="HOUSES"
);

# %%
df_fear.plot(
    kind="scatter",
    x="DEBT",
    y="HOUSES"
);
